# %%
import numpy as np
import pandas as pd
import scanpy.api as sc
from vpolo.alevin import parser

sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
results_file = '../salmon_mccarroll_out/mccarroll.h5ad'
sc.settings.set_figure_params(dpi=80)

mydata = parser.read_quants_bin("/home/fgao/Data_single_cell/kallisto_benchmark/salmon_mccarroll_out/")
mydata_t = mydata.T
mydata_t.to_csv('../salmon_mccarroll_out/mccarroll.csv', sep=',')
# Out:
# scanpy==1.3.2 anndata==0.6.10 numpy==1.15.1 scipy==1.1.0 pandas==0.23.0 scikit-learn==0.19.1 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1
# /home/fgao/Data_single_cell/kallisto_benchmark/salmon_mccarroll_out/alevin
#  Done reading 800 cells
# Read total 825 cells
# Found total 4263108.0 reads

# %%
data = pd.read_csv('../salmon_mccarroll_out/mccarroll.csv', index_col=0)
data.index = [i[0] for i in data.index.str.split(".")]
gene = pd.read_table('../10XGv2_brain2k_out/outs/raw_gene_bc_matrices/mouse_10XGv2_primary/genes.tsv', index_col=0, header=None)
mydata_symbol = pd.merge(gene, data, left_index=True, right_index=True)
mydata_symbol.index=mydata_symbol[1]
mydata_symbol2=mydata_symbol.drop([1],axis=1)
mydata_symbol2
mydata_symbol2.T.to_csv('../salmon_mccarroll_out/mccarroll_symbol.csv', sep=',')

# %%
adata = sc.read_csv('../salmon_mccarroll_out/mccarroll_symbol.csv')
adata.var_names_make_unique()
#gene_ids = pd.read_csv('../salmon_brain2k_out/alevin/quants_mat_cols.txt')
#bc = pd.read_csv('../salmon_brain2k_out/alevin/quants_mat_rows.txt')
#mart = pd.read_table('../index/mart_export_mouse.txt', index_col=0)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
sc.pp.filter_cells(adata, min_genes=100)
sc.pp.filter_genes(adata, min_cells=2)
mito_genes = [name for name in adata.var.index if name.startswith('mt-')]
# for each cell compute fraction of counts in mito genes vs. all genes
# the `.A1` is only necessary as X is sparse to transform to a dense array after summing
adata.obs['percent_mito'] = np.sum(
    adata[:, mito_genes].X, axis=1) / np.sum(adata.X, axis=1)
# add the total counts per cell as observations-annotation to adata
adata.obs['n_counts'] = adata.X.sum(axis=1)
# Out:
# filtered out 32 cells that have less than 100 genes expressed
# filtered out 16356 genes that are detected in less than 2 cells

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 793 × 18770
#     obs: 'n_genes', 'percent_mito', 'n_counts'
#     var: 'n_cells'

# %%
adata = adata[adata.obs['n_genes'] < 2500, :]
adata = adata[adata.obs['percent_mito'] < 0.2, :]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 451 × 18770
#     obs: 'n_genes', 'percent_mito', 'n_counts'
#     var: 'n_cells'

# %%
sc.pp.log1p(adata)
#sc.pp.regress_out(adata, ['n_counts', 'percent_mito'])

# %%
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=30)
sc.tl.umap(adata)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:06.05) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.71) --> added
#     'X_umap', UMAP coordinates (adata.obsm)

# %%
sc.tl.louvain(adata, resolution=2.4)
sc.pl.umap(adata, color=['louvain'])
# Out:
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 14 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)

# %%
sc.tl.tsne(adata, n_pcs=30)
sc.pl.tsne(adata, color=['louvain'])
# Out:
# computing tSNE
#     using 'X_pca' with n_pcs = 30
# WARNING: Consider installing the package MulticoreTSNE (https://github.com/DmitryUlyanov/Multicore-TSNE). Even for n_jobs=1 this speeds up the computation considerably and might yield better converged results.
#     using sklearn.manifold.TSNE with a fix by D. DeTomaso
#     finished (0:00:10.13) --> added
#     'X_tsne', tSNE coordinates (adata.obsm)

# %%
sc.tl.rank_genes_groups(adata, 'louvain', method='t-test', corr_method='benjamini-hochberg')
# Out:
# ranking genes
#     finished (0:00:00.54) --> added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids

# %%
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
#pd.DataFrame({group + '_' + key: result[key][group]
#    for group in groups for key in ['names', 'scores','logfoldchanges','pvals','pvals_adj']}).head(20)

# %%
marker_genes = ['Pax6', 'Gad1', 'Slc6a9', 'Opn1mw', 'Vsx2', 'Rlbp1']
sc.pl.dotplot(adata, marker_genes, groupby='louvain')

# %%
sc.pl.stacked_violin(adata, marker_genes, groupby='louvain', rotation=90)
